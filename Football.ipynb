# %%
# pip install soccer-data-api
# pip install lxml
# pip install beautifulsoup4

# %%
# data from https://fbref.com/en/
# data from https://www.transfermarkt.co.uk

import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
########################################################################
## Transfermarkt

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

html_text = requests.get('https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/11', headers=headers).text
soup = BeautifulSoup(html_text, 'lxml')
player_ramsdale = soup.find('tr', class_ = ['odd', 'even'])


ramsdale_info = player_ramsdale.find('td', class_ = 'hide').text

# %%
players = soup.find_all('td', class_ = 'hide', itemprop='athlete')
# players

# %%
########################################################################
## https://fbref.com
## Premier League Table

html_text = requests.get('https://fbref.com/en/comps/9/Premier-League-Stats').text
soup = BeautifulSoup(html_text, 'lxml')


x = soup.find('table', class_ = "stats_table sortable min_width")


## An array to store table header
headers = []

for i in range(20):
    y = x.find_all('th')[i]
    headers.append(y['aria-label'])  # This shows full text
#     headers.append(y.text)  # This shows abbreviated text
    
    
## Turn headers into dataframe
df = pd.DataFrame(columns = headers)


## Get data from the rest of the table and save it to the previous dataframe
for row in x.find_all('tr')[1:]:
    data = row.find_all(['td', 'th'])
    row_data = [td.text.strip() for td in data]
    length = len(df)
    df.loc[length] = row_data


df
# Out:
#    Rank            Squad Matches Played Wins Draws Losses Goals For  \
# 0     1          Arsenal              3    3     0      0         9
# 1     2  Manchester City              3    2     1      0         9
# 2     3     Leeds United              3    2     1      0         7
# 3     4        Tottenham              3    2     1      0         7
# 4     5         Brighton              3    2     1      0         4
# 5     6    Newcastle Utd              3    1     2      0         5
# 6     7           Fulham              3    1     2      0         5
# 7     8        Brentford              3    1     1      1         8
# 8     9   Crystal Palace              3    1     1      1         4
# 9    10  Nott'ham Forest              3    1     1      1         2
# 10   11      Southampton              3    1     1      1         5
# 11   12          Chelsea              3    1     1      1         3
# 12   13      Aston Villa              3    1     0      2         3
# 13   14   Manchester Utd              3    1     0      2         3
# 14   15      Bournemouth              3    1     0      2         2
# 15   16        Liverpool              3    0     2      1         4
# 16   17          Everton              3    0     1      2         2
# 17   18           Wolves              3    0     1      2         1
# 18   19   Leicester City              3    0     1      2         5
# 19   20         West Ham              3    0     0      3         0
#
#    Goals Against Goal Difference Points Points/Game   xG xG Allowed  \
# 0              2              +7      9        3.00  5.4        1.8
# 1              3              +6      7        2.33  6.6        2.3
# 2              3              +4      7        2.33  4.6        3.0
# 3              3              +4      7        2.33  4.1        2.8
# 4              1              +3      7        2.33  4.2        2.6
# 5              3              +2      5        1.67  4.0        4.1
# 6              4              +1      5        1.67  4.4        4.1
# 7              5              +3      4        1.33  3.7        3.2
# 8              4               0      4        1.33  5.5        4.0
# 9              3              -1      4        1.33  2.8        5.9
# 10             7              -2      4        1.33  2.3        3.8
# 11             5              -2      4        1.33  3.7        3.5
# 12             6              -3      3        1.00  3.5        5.0
# 13             7              -4      3        1.00  4.1        4.9
# 14             7              -5      3        1.00  0.9        4.0
# 15             5              -1      2        0.67  5.1        4.5
# 16             4              -2      1        0.33  3.8        4.3
# 17             3              -2      1        0.33  2.7        3.4
# 18             8              -3      1        0.33  1.5        3.7
# 19             5              -5      0        0.00  3.2        5.3
#
#    xG Difference xG Difference/90 Last 5 Attendance/Game  \
# 0           +3.5            +1.18  W W W          60,033
# 1           +4.3            +1.45  W W D
# 2           +1.6            +0.52  W D W          36,360
# 3           +1.4            +0.46  W D W          61,515
# 4           +1.6            +0.54  W D W          31,552
# 5           -0.2            -0.06  W D D          52,252
# 6           +0.3            +0.10  D D W          22,003
# 7           +0.5            +0.16  D W L
# 8           +1.6            +0.53  L D W          12,643
# 9           -3.2            -1.06  L W D          29,281
# 10          -1.6            -0.52  L D W
# 11          +0.3            +0.09  W D L          39,946
# 12          -1.5            -0.51  L W L          41,883
# 13          -0.7            -0.24  L L W          36,856
# 14          -3.1            -1.03  W L L          10,718
# 15          +0.6            +0.21  D D L
# 16          -0.5            -0.18  L L D          39,263
# 17          -0.6            -0.21  L D L          31,178
# 18          -2.3            -0.76  D L L          31,322
# 19          -2.1            -0.69  L L L          31,222
#
#                           Top Team Scorer         Goalkeeper Notes
# 0   Martin Ødegaard, Gabriel Jesus... - 2     Aaron Ramsdale
# 1                      Erling Haaland - 3            Ederson
# 2                             Rodrigo - 4      Illan Meslier
# 3                          Harry Kane - 2        Hugo Lloris
# 4                         Pascal Groß - 2     Robert Sánchez
# 5                       Callum Wilson - 2          Nick Pope
# 6                 Aleksandar Mitrović - 3        Marek Rodák
# 7            Josh Dasilva, Ivan Toney - 2         David Raya
# 8                       Wilfried Zaha - 3     Vicente Guaita
# 9      Brennan Johnson, Taiwo Awoniyi - 1     Dean Henderson
# 10                          Che Adams - 2       Gavin Bazunu
# 11           Jorginho, Reece James... - 1      Edouard Mendy
# 12      Emi Buendía, Ollie Watkins... - 1  Emiliano Martínez
# 13      Marcus Rashford, Jadon Sancho - 1       David de Gea
# 14     Jefferson Lerma, Kieffer Moore - 1       Mark Travers
# 15                      Mohamed Salah - 2            Alisson
# 16                       Demarai Gray - 1    Jordan Pickford
# 17                     Daniel Podence - 1            José Sá
# 18                     James Maddison - 2         Danny Ward
# 19                                          Łukasz Fabiański

# %%
## Arsenal Players

players_page = requests.get('https://fbref.com/en/squads/18bb7c10/Arsenal-Stats').text
soup = BeautifulSoup(players_page, 'lxml')

x = soup.find('table', class_ = "stats_table sortable min_width")


# headers = []

# for columns in x.find_all('tr')[1:]:
#     data = columns.find_all(['th'])
#     row_data = [th.text.strip() for th in data]
#     headers.append(row_data['aria-label'])

# headers

# %%
headers = []

for i in range(5):
    y = x.find_all('th', class_ = 'over_header center group_start')[i]
    headers.append(y.text)  # This shows full text


## Insert empty header to the first column
headers.insert(0, '')
headers.insert(0, '')
headers.insert(0, '')
headers.insert(0, '')
headers.insert(0, '')
headers.insert(5, 'Playing Time')
headers.insert(5, 'Playing Time')
headers.insert(8, 'Performance')
headers.insert(8, 'Performance')
headers.insert(8, 'Performance')
headers.insert(8, 'Performance')
headers.insert(8, 'Performance')
headers.insert(8, 'Performance')
headers.insert(15, 'Per 90 Minutes')
headers.insert(15, 'Per 90 Minutes')
headers.insert(15, 'Per 90 Minutes')
headers.insert(15, 'Per 90 Minutes')
headers.insert(20, 'Expected')
headers.insert(20, 'Expected')
headers.insert(20, 'Expected')
headers.insert(24, 'Per 90 Minutes')
headers.insert(24, 'Per 90 Minutes')
headers.insert(24, 'Per 90 Minutes')
headers.insert(24, 'Per 90 Minutes')
headers.insert(24, 'Per 90 Minutes')

df = pd.DataFrame(columns = headers)
df



headers2 = []

for i in range(30):
    y = x.find_all('th', class_ = ['poptip left', 'poptip center', 'poptip center group_start', 'poptip hide_non_quals center group_start', 'poptip hide_non_quals center'])[i]
    headers2.append(y.text)  # This shows full text


# ## Insert empty header to the first column
# headers.insert(0, '')

headers_m = (headers, headers2)

df2 = pd.DataFrame(columns = headers2)
df2
# Out:
# Empty DataFrame
# Columns: [Player, Nation, Pos, Age, MP, Starts, Min, 90s, Gls, Ast, G-PK, PK, PKatt, CrdY, CrdR, Gls, Ast, G+A, G-PK, G+A-PK, xG, npxG, xA, npxG+xA, xG, xA, xG+xA, npxG, npxG+xA, Matches]
# Index: []
#
# [0 rows x 30 columns]

# %%
np.savetxt('myfile.csv', headers_m, fmt='%s')

df = pd.read_csv(('myfile.csv'), header=[0,1])
print (df)
# Out:
# Empty DataFrame
# Columns: [(     Playing Time Playing Time Playing Time Performance Performance Performance Performance Performance Performance Performance Per 90 Minutes Per 90 Minutes Per 90 Minutes Per 90 Minutes Per 90 Minutes Expected Expected Expected Expected Per 90 Minutes Per 90 Minutes Per 90 Minutes Per 90 Minutes Per 90 Minutes Per 90 Minutes, Player Nation Pos Age MP Starts Min 90s Gls Ast G-PK PK PKatt CrdY CrdR Gls Ast G+A G-PK G+A-PK xG npxG xA npxG+xA xG xA xG+xA npxG npxG+xA Matches)]
# Index: []
